# %% [markdown]
# # Pulsar Folding and Searching
#
# Pulsar searching is a very time and compute intensive task. Searching for repeating signals within noisy data is a difficult issue alone, plus the fact massive volume of data and you got yourself a very difficult problem.
#
# This notebook illustrates the fundemental algorithms that are used for searching and detecting regular pusles within radio spectrograms.
#
# First we start off with downloading the data and `BLIMPY` which is an I/O tool developed to interface with the radio data!

# %%
# !pip install blimpy
# !wget http://blpd13.ssl.berkeley.edu/borisov/AGBT19B_999_124/spliced_blc40414243444546o7o0515253545556o7o061626364656667_guppi_58837_86186_PSR_B0355+54_0013.gpuspec.8.0001.fil
# !wget http://blpd13.ssl.berkeley.edu/dl/GBT_58402_64873_J1509+5531_time.h5
# http://ipta.phys.wvu.edu/files/student-week-2017/IPTA2017_KuoLiu_pulsartiming.pdf

# %% [markdown]
# # Loading Data
#
# First we load the data. NOTE targets with the starting name of PSR are radio scans of known pulsars! On the other hand files starting with HIP are catelogued stars that shouldn't have pulsar characteristics. If you wish to learn more about the data checkout https://ui.adsabs.harvard.edu/abs/2019PASP..131l4505L/abstract
#
# The header information gives vital info regarding the observational setup for the telescope. For example, the sensitivity of time or frequency or the range of frequency

# %%
from blimpy import Waterfall
import pylab as plt
import numpy as np
import math
from scipy import stats, interpolate
# %matplotlib inline


header = Waterfall('/content/spliced_blc40414243444546o7o0515253545556o7o061626364656667_guppi_58837_86186_PSR_B0355+54_0013.gpuspec.8.0001.fil',load_data=True)
header.info()

obs = Waterfall('/content/spliced_blc40414243444546o7o0515253545556o7o061626364656667_guppi_58837_86186_PSR_B0355+54_0013.gpuspec.8.0001.fil', 
               t_start=0,t_stop= 60000,max_load=10)
# Loads data into numpy array 
data = obs.data
data.shape
# Out:
# blimpy.io.base_reader WARNING  Selection size of 8.17 GB, exceeding our size limit 1.00 GB. Instance created, header loaded, but data not loaded, please try another (t,v) selection.
#
# --- File Info ---
#      rawdatafile :
#      source_name :                     PSR_B0355+54
#       machine_id :                               10
#     telescope_id :                                6
#          src_raj :                      3:58:53.496
#          src_dej :                      54:13:14.88
#         az_start :                              0.0
#         za_start :                              0.0
#        data_type :                                1
#             fch1 :            11251.28173828125 MHz
#             foff :                -0.3662109375 MHz
#           nchans :                            10240
#           nbeams :                                0
#            ibeam :                                0
#            nbits :                                8
#    tstart (ISOT) :          2019-12-20T23:56:26.000
#     tstart (MJD) :                58837.99752314815
#            tsamp :            0.0003495253333333333
#             nifs :                                1
#
# Num ints in file :                           857088
#       File shape :               (857088, 1, 10240)
# --- Selection Info ---
# Data selection shape :               (857088, 1, 10240)
# Minimum freq (MHz) :                 7501.28173828125
# Maximum freq (MHz) :                11251.28173828125
# blimpy.io.base_reader WARNING  Setting data limit != 1GB, please handle with care!
# (60000, 1, 10240)

# %%
# Here we plot the integrated signal over time.
obs.plot_spectrum()
# Out:
# extracting integration 0...

# %%
fig = plt.figure(figsize=(10, 6))
plt.imshow(data[:2000,0,:2000], aspect='auto')
plt.colorbar()

# %% [markdown]
# # Band Pass Removal
# To remove the bandpass, we use spline lines to fit each channel to obtain a model of the bandpass of that channel. By using splines, we are able to fit the bandpass without fitting the more significant signals.
#
# If you want more details on this checkout https://github.com/FX196/SETI-Energy-Detection for more detailed explantion

# %%
average_power = np.zeros((data.shape[2]))
shifted_power = np.zeros((int(data.shape[2]/8)))
x=[]
print("Fitting Spline")
for i in range(0,data.shape[2],8):
  if i%2500==0:
    print("Freq array index:"+ str(i))
  shifted_power[int(i/8)] = data[:,0,i].mean(axis=0)
  x.append(i)

tck = interpolate.splrep(x, shifted_power, s=0)
xnew = np.arange(0, 10232,1)
ynew = interpolate.splev(xnew, tck, der=0)

print("Finding the average intensitiy over time per frequency")
for i in range(data.shape[2]):
  if i%2500==0:
    print("Freq array index:"+ str(i))
  average_power[i]= data[:,0,i].mean(axis=0)
# Out:
# Fitting Spline
# Freq array index:0
# Freq array index:5000
# Freq array index:10000
# Finding the average intensitiy over time per frequency
# Freq array index:0
# Freq array index:2500
# Freq array index:5000
# Freq array index:7500
# Freq array index:10000

# %%
plt.figure()
plt.plot(xnew, ynew)
plt.title('Spline Fit')
plt.xlabel("Fchans")
plt.ylabel("Power")
# Out:
# Text(0, 0.5, 'Power')

# %%
plt.figure()
plt.plot(average_power)
plt.title('Average Power')
plt.xlabel("Fchans")
plt.ylabel("Power")
# Out:
# Text(0, 0.5, 'Power')

# %%
# We now subtract the spline from the original data. 
print("Correcting Spline Fit")
prepros = np.zeros(data.shape)
for i in range(data.shape[2]-8):
  if i%2500==0:
    print("Freq array index:"+ str(i))
  prepros[:,0,i]  = data[:,0,i] - ynew[i]


plt.figure()
plt.plot(prepros[:,0,:] .mean(axis = 0))
plt.title('Average Power')
plt.xlabel("Fchans")
plt.ylabel("Power")

fig = plt.figure(figsize=(10, 6))
plt.imshow(prepros[:2000,0,:2000], aspect='auto')
plt.title('Cleaned Data')
plt.xlabel("Fchans (absolute)")
plt.ylabel("Time (s)")
plt.colorbar()
# Out:
# Correcting Spline Fit
# Freq array index:0
# Freq array index:2500
# Freq array index:5000
# Freq array index:7500
# Freq array index:10000

# %% [markdown]
# # Detecting Pulses - Fourier Transforms and Folding
#
# What we do next is we take the fast fourier transform of the original signal and take the magnitude of the fourier transform. A large magnitude indicates a potential period within that signal. AKA a repeating signal!
#
# If the magnitude of the fourier transform is above a certain threshold we can consider it as a candidate.

# %%
# Functions to determine SNR and TOP candidates
def SNR(arr):
  index = np.argmax(arr)
  average_noise = arr.mean(axis=0)
  return math.log(arr[index]/average_noise) 

def top(arr, top = 10):
  candidate = []
  # Delete the first and second element fourier transform
  arr[0]=0
  arr[1]=0
  for i in range(top):
    index = np.argmax(arr)
    candidate.append(index)
    arr[index]=0
  return candidate

# %%
#  Preforming the fourier transform.
# %matplotlib inline
import scipy.fftpack
from scipy.fft import fft
N = 60000
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = prepros[:,0,:].mean(axis=1)
yf = fft(y)

xf = np.linspace(0.0, 1.0/(2.0*T), N//2)

# Magintude of the fourier transform
# Between 0.00035 and 3.5 seconds
mag = np.abs(yf[:30000])
candidates = top(mag, top=15)
plt.plot(2.0/N * mag[1:])
plt.grid()
plt.title('Fourier Transform of Signal')
plt.xlabel("Periods")
plt.ylabel("Magnitude of Fourier Transform")
plt.show()

print("Signal To Noise Ratio for the Fourier Transform is: "+str(SNR(mag)))
print("Most likely Candidates are: "+str(candidates))
# Out:
# Signal To Noise Ratio for the Fourier Transform is: 3.3377138865513154
# Most likely Candidates are: [134, 268, 402, 536, 1073, 1207, 805, 939, 1341, 670, 1475, 671, 1609, 3, 537]

# %% [markdown]
# # Folding Algorithm
#
# The idea of the folding algorithm is to see if the signal forms a consistent profile as you fold / integrate the values together. If the profile appears consistent/stable then you're looking at an accurate reading of the pulsar's period! It is used to confirm the implications drawn from the fourier transform. It also forms a "finger print" of the pulsar!

# %%
#  Lets take an example of such a period!
period = 537
fold = np.zeros((period, data.shape[2]))
multiples = int(data.data.shape[0]/period)
results = np.zeros((period))

for i in range(multiples-1):
  fold[:,:]=data[i*period:(i+1)*period,0,:]+ fold

results = fold.mean(axis=1)
results = results - results.min()
results = results / results.max()

print(SNR(results))

plt.plot(results)
# Out:
# 1.6648318305384018

# %%
from scipy import stats 
data= prepros
period = 537
fold = np.zeros((period, data.shape[2]))
multiples = int(data.data.shape[0]/period)
results = np.zeros((period))

for i in range(multiples-1):
  fold[:,:]=data[i*period:(i+1)*period,0,:]+ fold
  results = fold.mean(axis=1)
  results = results - results.min()
  results = results / results.max()
  #  Generates multiple frames of the graph as it folds! 
  plt.plot(results)
  plt.title('Folded Signal Period '+str(period*0.000349)+" seconds| Fold Iteration: "+str(i))
  plt.xlabel("Time (Multiples of 0.00035s)")
  plt.ylabel("Normalized Integrated Signal")
  plt.savefig('/content/drive/My Drive/Deeplearning/Pulsars/output/candidates/CAN_3/multi_chan_'+str(period)+'_'+str(i)+'.png')
  plt.close()
  
results = fold.mean(axis=1)
results = results - results.min()
results = results / results.max()

print("The Signal To Noise of the Fold is: "+str(SNR(results)))
plt.plot(results)
# Out:
# The Signal To Noise of the Fold is: 1.6648318305384018

# %%
sensitivity = 1
start = 100
max = 1000
snrs = []
for period in range(start,max,sensitivity):
  
  fold = np.zeros((period, data.shape[2]))
  results = np.zeros((period))
  multiples = int(data.data.shape[0]/period)

  for i in range(multiples-1):
    fold[:,:]=data[i*period:(i+1)*period,0,:]+ fold
  
  results = fold.mean(axis=1)
  results = results - results.min()
  results = results/results.max()

  snr_single = SNR(results)
  snrs.append(snr_single)
  print("Period folding... "+str(period)+ " SNR: "+str(snr_single))
  plt.plot(results)
  plt.title('Folded Signal Period '+str(period*0.000349)+" seconds")
  plt.xlabel("Time (Multiples of 0.00035s)")
  plt.ylabel("Normalized Integrated Signal")
  plt.savefig('/content/drive/My Drive/Deeplearning/Pulsars/output/multichan/multi_chan_'+str(period)+'.png')
  plt.close()
# Out:
# Period folding... 100 SNR: 0.8554869223097198
# Period folding... 101 SNR: 0.8858755216046127
# Period folding... 102 SNR: 0.7930469048851703
# Period folding... 103 SNR: 0.6338861866663205
# Period folding... 104 SNR: 1.0912778316900043
# Period folding... 105 SNR: 0.818060103930893
# Period folding... 106 SNR: 0.9874298627884731
# Period folding... 107 SNR: 0.8408116106471304
# Period folding... 108 SNR: 1.0108183960473391
# Period folding... 109 SNR: 1.085770587608241
# Period folding... 110 SNR: 0.7336221816532773
# Period folding... 111 SNR: 1.2400636980697408
# Period folding... 112 SNR: 0.7782414544478573
# Period folding... 113 SNR: 0.8706301105385906
# Period folding... 114 SNR: 0.6474983815403562
# Period folding... 115 SNR: 0.9274532105284131
# Period folding... 116 SNR: 0.9871905778409806
# Period folding... 117 SNR: 0.6870768550286704
# Period folding... 118 SNR: 0.8168259157715948
# Period folding... 119 SNR: 0.9582528839545301
# Period folding... 120 SNR: 0.5390550463101076
# Period folding... 121 SNR: 1.0509578925810692
# Period folding... 122 SNR: 0.9900974846598389
# Period folding... 123 SNR: 0.8480216741560773
# Period folding... 124 SNR: 0.9304645749984092
# Period folding... 125 SNR: 0.7875690652053791
# Period folding... 126 SNR: 0.8721159185369995
# Period folding... 127 SNR: 0.9352757339039212
# Period folding... 128 SNR: 1.1177590857151705
# Period folding... 129 SNR: 1.0494580285608586
# Period folding... 130 SNR: 1.0863119217036228
# Period folding... 131 SNR: 1.0598816552860906
# Period folding... 132 SNR: 0.97097604903488
# Period folding... 133 SNR: 0.8348858148988632
# Period folding... 134 SNR: 0.8774354819889459
# Period folding... 135 SNR: 1.0200460719337943
# Period folding... 136 SNR: 0.8169429603339821
# Period folding... 137 SNR: 0.7568151992054261
# Period folding... 138 SNR: 0.9617952800773703
# Period folding... 139 SNR: 0.6670555106369389
# Period folding... 140 SNR: 0.9177206380257416
# Period folding... 141 SNR: 0.7370881012246151
# Period folding... 142 SNR: 0.9484493887502786
# Period folding... 143 SNR: 0.9595310094393936
# Period folding... 144 SNR: 1.0578278247319142
# Period folding... 145 SNR: 0.9548910787590126
# Period folding... 146 SNR: 0.800251581543812
# Period folding... 147 SNR: 0.9631818533416499
# Period folding... 148 SNR: 1.2933363965795135
# Period folding... 149 SNR: 1.0837040693416458
# Period folding... 150 SNR: 0.9697324007503307
# Period folding... 151 SNR: 1.0274291905170088
# Period folding... 152 SNR: 0.9317803839997678
# Period folding... 153 SNR: 0.8815199989836221
# Period folding... 154 SNR: 1.2311507369546957
# Period folding... 155 SNR: 1.0027117968686543
# Period folding... 156 SNR: 0.6955213447973049
# Period folding... 157 SNR: 1.0728595839558064
# Period folding... 158 SNR: 0.9118472524289343
# Period folding... 159 SNR: 1.206267592234613
# Period folding... 160 SNR: 1.1421799526799363
# Period folding... 161 SNR: 1.157442676466551
# Period folding... 162 SNR: 0.8646520271358743
# Period folding... 163 SNR: 1.0759374077181327
# Period folding... 164 SNR: 0.9609588112030797
# Period folding... 165 SNR: 0.8750364712074125
# Period folding... 166 SNR: 1.1328233729283939
# Period folding... 167 SNR: 1.0082101296981945
# Period folding... 168 SNR: 0.8573123694625144
# Period folding... 169 SNR: 0.8718029765468448
# Period folding... 170 SNR: 0.9009606440784668
# Period folding... 171 SNR: 0.8491781406893558
# Period folding... 172 SNR: 0.745407982598845
# Period folding... 173 SNR: 1.0084787496052952
# Period folding... 174 SNR: 1.1409001683973297
# Period folding... 175 SNR: 0.8386337916542577
# Period folding... 176 SNR: 0.652965949525897
# Period folding... 177 SNR: 0.9957126829999262
# Period folding... 178 SNR: 0.9626297085169203
# Period folding... 179 SNR: 1.6959113237770962
# Period folding... 180 SNR: 0.6875760786148243
# Period folding... 181 SNR: 1.2561802395268957
# Period folding... 182 SNR: 1.018569563837374
# Period folding... 183 SNR: 0.8051992924911548
# Period folding... 184 SNR: 0.9859296342360105
# Period folding... 185 SNR: 1.2747087878256822
# Period folding... 186 SNR: 1.2063574790750793
# Period folding... 187 SNR: 0.7982857030858685
# Period folding... 188 SNR: 0.9502117321441776
# Period folding... 189 SNR: 0.960033607494466
# Period folding... 190 SNR: 0.926712466594376
# Period folding... 191 SNR: 0.8429130822928185
# Period folding... 192 SNR: 1.0506342342590027
# Period folding... 193 SNR: 1.1877352207246223
# Period folding... 194 SNR: 1.0822460732329122
# Period folding... 195 SNR: 0.9578694072351929
# Period folding... 196 SNR: 1.075530160786595
# Period folding... 197 SNR: 1.1114666343398325
# Period folding... 198 SNR: 0.9851354606855328
# Period folding... 199 SNR: 0.7221980996269447
# Period folding... 200 SNR: 0.9150004202703641
# Period folding... 201 SNR: 1.0691090922444313
# Period folding... 202 SNR: 1.021835029036929
# Period folding... 203 SNR: 1.2616326329396688
# Period folding... 204 SNR: 0.8960159564080313
# Period folding... 205 SNR: 0.8713203897781545
# Period folding... 206 SNR: 0.9920676592766161
# Period folding... 207 SNR: 0.8695739523747541
# Period folding... 208 SNR: 1.1571999356860403
# Period folding... 209 SNR: 1.1375533407840726
# Period folding... 210 SNR: 0.8199136534940191
# Period folding... 211 SNR: 1.0373412947187135
# Period folding... 212 SNR: 0.9728803380142423
# Period folding... 213 SNR: 1.0032292878558517
# Period folding... 214 SNR: 1.0867873652184505
# Period folding... 215 SNR: 1.1316537368091613
# Period folding... 216 SNR: 1.175978186592323
# Period folding... 217 SNR: 0.9744238907256649
# Period folding... 218 SNR: 1.3072230847241637
# Period folding... 219 SNR: 1.0864660926919156
# Period folding... 220 SNR: 1.0147248934129383
# Period folding... 221 SNR: 1.0597782445680966
# Period folding... 222 SNR: 1.4203540305622706
# Period folding... 223 SNR: 1.0498012253800852
# Period folding... 224 SNR: 1.2114014914945688
# Period folding... 225 SNR: 1.0669881354663109
# Period folding... 226 SNR: 1.2797096724112786
# Period folding... 227 SNR: 0.860273683511078
# Period folding... 228 SNR: 0.8729732077259765
# Period folding... 229 SNR: 1.0324239874683807
# Period folding... 230 SNR: 1.086874773331513
# Period folding... 231 SNR: 0.9688851513088792
# Period folding... 232 SNR: 1.1384416477583479
# Period folding... 233 SNR: 1.199354902573021
# Period folding... 234 SNR: 0.9599597401917275
# Period folding... 235 SNR: 1.0922056538378933
# Period folding... 236 SNR: 1.0002763366095266
# Period folding... 237 SNR: 0.9281402311958574
# Period folding... 238 SNR: 1.3538009759522294
# Period folding... 239 SNR: 0.9546020912410546
# Period folding... 240 SNR: 1.0875566702554738
# Period folding... 241 SNR: 0.9163829788829743
# Period folding... 242 SNR: 1.0475377081301402
# Period folding... 243 SNR: 1.0277779679985721
# Period folding... 244 SNR: 1.1100316954538785
# Period folding... 245 SNR: 0.9109757895719719
# Period folding... 246 SNR: 0.9471840458642488
# Period folding... 247 SNR: 1.177656625228653
# Period folding... 248 SNR: 1.1421041209851934
# Period folding... 249 SNR: 0.955375517327353
# Period folding... 250 SNR: 0.904876082994262
# Period folding... 251 SNR: 0.9404027226193657
# Period folding... 252 SNR: 1.283926267629171
# Period folding... 253 SNR: 0.9739473603392734
# Period folding... 254 SNR: 1.0043662936924813
# Period folding... 255 SNR: 1.4138068020035397
# Period folding... 256 SNR: 1.0027910566511513
# Period folding... 257 SNR: 1.0247829843294385
# Period folding... 258 SNR: 1.0306384281407837
# Period folding... 259 SNR: 1.0884961162176237
# Period folding... 260 SNR: 1.2166337138256855
# Period folding... 261 SNR: 1.4576781250928745
# Period folding... 262 SNR: 1.1071884280576243
# Period folding... 263 SNR: 1.1340423206781645
# Period folding... 264 SNR: 1.2303749774266322
# Period folding... 265 SNR: 1.0307387374607313
# Period folding... 266 SNR: 1.0081508234886556
# Period folding... 267 SNR: 1.1007113840275393
# Period folding... 268 SNR: 1.1575603701868167
# Period folding... 269 SNR: 1.0327840266850337
# Period folding... 270 SNR: 0.866787447157177
# Period folding... 271 SNR: 1.2084183853396755
# Period folding... 272 SNR: 1.055306056283282
# Period folding... 273 SNR: 1.0813534183691662
# Period folding... 274 SNR: 1.1666536910700296
# Period folding... 275 SNR: 1.0454932375439219
# Period folding... 276 SNR: 0.9949944472660691
# Period folding... 277 SNR: 0.9891062281215299
# Period folding... 278 SNR: 0.9297563049914187
# Period folding... 279 SNR: 1.4333781141584185
# Period folding... 280 SNR: 0.9629960325876961
# Period folding... 281 SNR: 1.134431257321703
# Period folding... 282 SNR: 0.9669455000397716
# Period folding... 283 SNR: 1.1228108819733444
# Period folding... 284 SNR: 0.9808634383233616
# Period folding... 285 SNR: 1.065045875682389
# Period folding... 286 SNR: 1.1328613688154365
# Period folding... 287 SNR: 1.0924444091062244
# Period folding... 288 SNR: 1.2649675986334303
# Period folding... 289 SNR: 1.276037672499536
# Period folding... 290 SNR: 1.121252732590192
# Period folding... 291 SNR: 1.0317658093636084
# Period folding... 292 SNR: 1.0729086400809607
# Period folding... 293 SNR: 1.0060671788944504
# Period folding... 294 SNR: 1.051977469564601
# Period folding... 295 SNR: 0.9233157352223944
# Period folding... 296 SNR: 1.3878849292773698
# Period folding... 297 SNR: 0.8973618306936262
# Period folding... 298 SNR: 1.0907627301853624
# Period folding... 299 SNR: 0.6016265754038055
# Period folding... 300 SNR: 0.8638187559959243
# Period folding... 301 SNR: 1.0822755251310265
# Period folding... 302 SNR: 1.1990746421394494
# Period folding... 303 SNR: 1.3881469789127479
# Period folding... 304 SNR: 1.2770860535564859
# Period folding... 305 SNR: 1.0087578665428454
# Period folding... 306 SNR: 1.0500233749319157
# Period folding... 307 SNR: 1.0578408696409987
# Period folding... 308 SNR: 1.3485907623508828
# Period folding... 309 SNR: 1.0274544787991593
# Period folding... 310 SNR: 1.1691131669434316
# Period folding... 311 SNR: 1.0232960813613239
# Period folding... 312 SNR: 1.2819845589966314
# Period folding... 313 SNR: 1.1104490147945436
# Period folding... 314 SNR: 1.1227629679501723
# Period folding... 315 SNR: 1.0771405226491546
# Period folding... 316 SNR: 1.0694773634296868
# Period folding... 317 SNR: 1.1149883149905129
# Period folding... 318 SNR: 0.9877381520408554
# Period folding... 319 SNR: 1.170615046029886
# Period folding... 320 SNR: 1.176767577106805
# Period folding... 321 SNR: 1.0714094269859875
# Period folding... 322 SNR: 1.3679165352928881
# Period folding... 323 SNR: 0.9871885129133626
# Period folding... 324 SNR: 1.2406527504623452
# Period folding... 325 SNR: 0.8873604676840321
# Period folding... 326 SNR: 1.249498191794055
# Period folding... 327 SNR: 1.024057471362948
# Period folding... 328 SNR: 1.0540600600419865
# Period folding... 329 SNR: 1.3145910394881823
# Period folding... 330 SNR: 1.0297216126029642
# Period folding... 331 SNR: 1.438788801456016
# Period folding... 332 SNR: 0.9933515665576488
# Period folding... 333 SNR: 1.0359883064134772
# Period folding... 334 SNR: 1.3925843563490863
# Period folding... 335 SNR: 0.9272007054933029
# Period folding... 336 SNR: 0.8221714231056636
# Period folding... 337 SNR: 1.0673682481497253
# Period folding... 338 SNR: 1.120739346066157
# Period folding... 339 SNR: 1.1407207387978953
# Period folding... 340 SNR: 1.1438302162010439
# Period folding... 341 SNR: 1.0214631872005853
# Period folding... 342 SNR: 1.16444444933411
# Period folding... 343 SNR: 0.8319220449854838
# Period folding... 344 SNR: 1.1359841617548991
# Period folding... 345 SNR: 1.1307074308042746
# Period folding... 346 SNR: 1.1310228971348693
# Period folding... 347 SNR: 0.9047697740755488
# Period folding... 348 SNR: 1.5571554398409824
# Period folding... 349 SNR: 1.2278626360504152
# Period folding... 350 SNR: 1.217379341888996
# Period folding... 351 SNR: 1.1000737895145358
# Period folding... 352 SNR: 1.0398131896182847
# Period folding... 353 SNR: 1.0370116733320782
# Period folding... 354 SNR: 1.06446727205594
# Period folding... 355 SNR: 1.241071882742293
# Period folding... 356 SNR: 1.1587837461838977
# Period folding... 357 SNR: 0.9843247612644039
# Period folding... 358 SNR: 1.7829623471474505
# Period folding... 359 SNR: 1.0007000273097377
# Period folding... 360 SNR: 1.0099322866184086
# Period folding... 361 SNR: 1.0998601645161166
# Period folding... 362 SNR: 1.233877058063635
# Period folding... 363 SNR: 1.488700280700615
# Period folding... 364 SNR: 1.1737033989719585
# Period folding... 365 SNR: 0.9200050201380426
# Period folding... 366 SNR: 1.089033950557525
# Period folding... 367 SNR: 1.1856647431866156
# Period folding... 368 SNR: 1.2503479614177027
# Period folding... 369 SNR: 1.1493651498530895
# Period folding... 370 SNR: 1.4913126558827117
# Period folding... 371 SNR: 1.1825563186376045
# Period folding... 372 SNR: 0.9732493053819807
# Period folding... 373 SNR: 1.0555704957261378
# Period folding... 374 SNR: 1.2831227337903222
# Period folding... 375 SNR: 0.9930592266190288
# Period folding... 376 SNR: 1.1349160840141064
# Period folding... 377 SNR: 1.1824754349019035
# Period folding... 378 SNR: 1.1816388568203802
# Period folding... 379 SNR: 0.9757260359102734
# Period folding... 380 SNR: 1.2046091836138697
# Period folding... 381 SNR: 1.3598855609127944
# Period folding... 382 SNR: 1.057390363830452
# Period folding... 383 SNR: 1.0330843299465378
# Period folding... 384 SNR: 1.1913954698350495
# Period folding... 385 SNR: 1.278550781736873
# Period folding... 386 SNR: 1.2960246183636748
# Period folding... 387 SNR: 1.0708520275087876
# Period folding... 388 SNR: 1.0855766205300907
# Period folding... 389 SNR: 1.238197069609642
# Period folding... 390 SNR: 1.1418716708516594
# Period folding... 391 SNR: 1.2194989860313792
# Period folding... 392 SNR: 1.0501380347861904
# Period folding... 393 SNR: 1.1648178043330788
# Period folding... 394 SNR: 1.3262289197737656
# Period folding... 395 SNR: 1.3684685359658961
# Period folding... 396 SNR: 1.2377949082628115
# Period folding... 397 SNR: 1.0774482330797792
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b6d18252d5dd> in <module>()
#      10
#      11   for i in range(multiples-1):
# ---> 12     fold[:,:]=data[i*period:(i+1)*period,0,:]+ fold
#      13
#      14   results = fold.mean(axis=1)
#
# KeyboardInterrupt:

# %%
plt.plot(snrs)
plt.title('SNR Per Folding Period')
plt.xlabel("Period")
plt.ylabel("SNR")
plt.savefig('/content/drive/My Drive/Deeplearning/Pulsars/output/SNR.png')

# %%
print(np.argmax(snrs))
print(snrs[795])
# 224
# Out:
# 795
# 0.014400618273742154

# %%
period = 30000
fold = np.zeros((period, data.shape[2]))
multiples = int(data.data.shape[0]/period)
results = np.zeros((period))

for i in range(multiples-1):
  fold[:,:]=data[i*period:(i+1)*period,0,:]+ fold

results = fold.mean(axis=1)
results = results - results.min()
results = results / results.max()

print(signaltonoise(results))

plt.plot(results)
